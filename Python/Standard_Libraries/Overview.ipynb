# %% [markdown]
# ## Standard Library
#
# ### Module: a single .py file.
# ### Package: collection of Modules organized in a directory.
# ### Library: Conceptual Group of multiple Packages. Example, (Numpy + Pandas)

# %%
import array
arr = array.array('i', [1,2,3])   # 'i' is a typecode 
print(arr)
# Out:
# array('i', [1, 2, 3])

# %%
## random 
import random 
print(random.randint(1,20))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 5
# banana

# %%
## File and Directory Access

import os 
print(os.getcwd())
# Out:
# e:\Coding_Revision\Coding_Practice-Revision\Python\Standard_Libraries

# %%
os.mkdir('test')

# %%
## High level operations on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json 
data = {'name':'Krish', 'age':25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Krish", "age": 25}
# <class 'str'>
# {'name': 'Krish', 'age': 25}
# <class 'dict'>

# %%
## csv
import csv
with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Krish', 32])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '32']

# %%
## DateTime

from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-04-14 19:22:47.315617
# 2026-04-13 19:22:47.315617

# %%
## Time 

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1776174819.5533974
# 1776174821.5557477

# %%
## Regular Expression

import re
pattern = r'\d+'   # 'd' for digits and '+' for more than one
text = 'There are 123 apples 456'
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
